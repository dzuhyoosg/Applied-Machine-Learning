# %% [markdown]
# ## Ziyu Song (zs363) CS 5785 Homework 0

# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# iris = datasets.load_iris() # if load directly from sklearn
iris = np.loadtxt('iris.data', delimiter = ',', dtype = str)
# print(iris)
type(iris)
irisDF = pd.DataFrame(iris[])
print(irisDF)
# Out:
#                 0
# 0             5.9
# 1             3.0
# 2             5.1
# 3             1.8
# 4  Iris-virginica

# %% [markdown]
# There are 150 instances. 4 attributes per sample. 3 different classes (species?). 50 samples for each species.

# %%
with open ('iris.data') as irisFile: 
    lines = [line.split() for line in irisFile]
# print(lines)
# type(lines)

# %%
sns.set()
# iris = sns.load_dataset('iris')
sns.pairplot(irisDF, hue = 'species', height = 2)
plt.savefig('iris_plot.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'species'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-739de2900662> in <module>
#       1 sns.set()
#       2 # iris = sns.load_dataset('iris')
# ----> 3 sns.pairplot(irisDF, hue = 'species', height = 2)
# ...

# %%
sns.set()
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue = 'species', height = 2)
plt.savefig('iris_plot.png')
